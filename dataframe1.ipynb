# %% [markdown]
# <a href="https://colab.research.google.com/github/debb-562/personal/blob/main/dataframe1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()   # opens file picker to choose one or more files
# Out:
#      <input type="file" id="files-faf59dea-459d-4fda-a88c-ee3f8b631d7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-faf59dea-459d-4fda-a88c-ee3f8b631d7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# show uploaded filenames
print("Uploaded files:", list(uploaded.keys()))
# Out:
# Uploaded files: ['Employee Sample Data.csv']

# %%
import pandas as pd

filename = 'Employee Sample Data.csv'
try:
    df = pd.read_csv(filename, encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(filename, encoding='latin1')

df.head()
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# 0  Research & Development  Female      Black   55    4/8/2016     $141,604
# 1           Manufacturing    Male      Asian   59  11/29/1997      $99,975
# 2     Speciality Products  Female  Caucasian   50  10/26/2006     $163,099
# 3           Manufacturing  Female  Caucasian   26   9/27/2019      $84,913
# 4           Manufacturing    Male      Asian   55  11/20/1995      $95,409
#
#   Bonus %        Country       City   Exit Date
# 0    15%   United States    Seattle  10/16/2021
# ...

# %%
df.columns
# Out:
# Index(['EEID', 'Full Name', 'Job Title', 'Department', 'Business Unit',
#        'Gender', 'Ethnicity', 'Age', 'Hire Date', 'Annual Salary', 'Bonus %',
#        'Country', 'City', 'Exit Date'],
#       dtype='object')

# %%
df['EEID']
# Out:
# 0      E02387
# 1      E04105
# 2      E02572
# 3      E02832
# 4      E01639
#         ...
# 995    E03094
# 996    E01909
# 997    E04398
# 998    E02521
# 999    E03545
# Name: EEID, Length: 1000, dtype: object

# %%
df['Country'][4]
# Out:
# 'United States'

# %%
df[['EEID', 'Job Title']]
# Out:
#        EEID                 Job Title
# 0    E02387                Sr. Manger
# 1    E04105       Technical Architect
# 2    E02572                  Director
# 3    E02832  Computer Systems Manager
# 4    E01639               Sr. Analyst
# ..      ...                       ...
# 995  E03094               Sr. Analyst
# 996  E01909                   Analyst
# 997  E04398                  Director
# 998  E02521               Sr. Analyst
# 999  E03545            Vice President
#
# [1000 rows x 2 columns]

# %%
df.loc[5, :]
# Out:
# EEID                             E00644
# Full Name                  Joshua Gupta
# Job Title        Account Representative
# Department                        Sales
# Business Unit                 Corporate
# Gender                             Male
# Ethnicity                         Asian
# Age                                  57
# Hire Date                     1/24/2017
# Annual Salary                  $50,994
# Bonus %                             0%
# Country                           China
# City                          Chongqing
# Exit Date                           NaN
# Name: 5, dtype: object

# %%
df.loc[3:9, :]
# Out:
#      EEID        Full Name                 Job Title  Department  \
# 3  E02832  Penelope Jordan  Computer Systems Manager          IT
# 4  E01639        Austin Vo               Sr. Analyst     Finance
# 5  E00644     Joshua Gupta    Account Representative       Sales
# 6  E01550      Ruby Barnes                   Manager          IT
# 7  E04332      Luke Martin                   Analyst     Finance
# 8  E04533    Easton Bailey                   Manager  Accounting
# 9  E03838  Madeline Walker               Sr. Analyst     Finance
#
#          Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# 3        Manufacturing  Female  Caucasian   26   9/27/2019      $84,913
# 4        Manufacturing    Male      Asian   55  11/20/1995      $95,409
# 5            Corporate    Male      Asian   57   1/24/2017      $50,994
# 6            Corporate  Female  Caucasian   27    7/1/2020     $119,746
# 7        Manufacturing    Male      Black   25   5/16/2020      $41,336
# ...

# %%
df.loc[2:10, ['EEID', 'Job Title', 'Full Name']]
# Out:
#       EEID                 Job Title        Full Name
# 2   E02572                  Director     Luna Sanders
# 3   E02832  Computer Systems Manager  Penelope Jordan
# 4   E01639               Sr. Analyst        Austin Vo
# 5   E00644    Account Representative     Joshua Gupta
# 6   E01550                   Manager      Ruby Barnes
# 7   E04332                   Analyst      Luke Martin
# 8   E04533                   Manager    Easton Bailey
# 9   E03838               Sr. Analyst  Madeline Walker
# 10  E00591                Sr. Manger     Savannah Ali
